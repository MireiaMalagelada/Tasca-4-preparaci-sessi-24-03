# %%
from sisl import *

# %%
molecule=Geometry.read("Timina_coord_15-atoms.xyz")

# %%
molecule.plot()

# %%
molecule.write("structure.fdf")

# %%
structure=Geometry.read("structure.fdf")

# %%
structure.plot()
