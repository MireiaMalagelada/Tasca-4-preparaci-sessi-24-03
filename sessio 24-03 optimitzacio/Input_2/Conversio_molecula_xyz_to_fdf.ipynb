# %%
from sisl import *

# %%
molecule=Geometry.read("mol_1_optimitzacio.xyz")

# %%
molecule.plot()

# %%
molecule.write("structure.fdf")

# %%
structure=Geometry.read("structure.fdf")

# %%
structure.plot()
